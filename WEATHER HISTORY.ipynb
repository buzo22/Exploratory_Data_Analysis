# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS ON WAETHER HISTORY DATASET
#
# BY CHIBUZO AKANA
#
# Data source - Kaggle.com

# %% [markdown]
# ### TABLE OF CONTENTS
#
# - INTRODUCTION
# - IMPORT LIBRARIES
# - LOAD DATA
# - CLEAN DATA
# - PREPARE DATA
# - ANALYSE DATA

# %% [markdown]
# #### INTRODUCTION
#
# This report is based on a weather history report. The major variables that will be looked into are; Temperature, Humidity, Wind Speed, Pressure, Weather Condition. Some questions were answered through this report that covered the analysis.

# %% [markdown]
# #### IMPORT LIBRARIES

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### LOAD DATA

# %%
df = pd.read_csv('weatherHistory.csv')
df
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
# This gives the number of rows and columns in the dataset
df.shape
# Out:
# (96453, 12)

# %%
# This shows info about the nature of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 8.8+ MB

# %%
# This shows the data types
df.dtypes
# Out:
# Formatted Date               object
# Summary                      object
# Precip Type                  object
# Temperature (C)             float64
# Apparent Temperature (C)    float64
# Humidity                    float64
# Wind Speed (km/h)           float64
# Wind Bearing (degrees)      float64
# Visibility (km)             float64
# Loud Cover                  float64
# Pressure (millibars)        float64
# Daily Summary                object
# dtype: object

# %%
df.rename(columns = {'Formatted Date': 'Date', 'Summary':'Weather', 'Precip Type':'Precip', 'Temperature (C)':'Temp', 'Apparent Temperature (C)':'App_Temp', 'Humidity':'Humi', 'Wind Speed (km/h)':'Wind_Speed', 'Wind Bearing (degrees)':'Wind_Bear', 'Visibility (km)':'Visibility', 'Loud Cover':'Loud', 'Pressure (millibars)':'Pressure', 'Daily Summer':'Daily_Weather'}, inplace=True)
df
# Out:
#                                 Date        Weather Precip       Temp  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy   rain   9.472222
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy   rain   9.355556
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy   rain   9.377778
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy   rain   8.288889
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy   rain   8.755556
# ...                              ...            ...    ...        ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy   rain  26.016667
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy   rain  24.583333
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy   rain  22.038889
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy   rain  21.522222
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy   rain  20.438889
#
#         App_Temp  Humi  Wind_Speed  Wind_Bear  Visibility  Loud  Pressure  \
# ...

# %% [markdown]
# #### ANALYSE DATA

# %% [markdown]
# ### Q. 1)  Find all the unique 'Wind Speed' values in the data.

# %%
df.Wind_Speed.unique()
# Out:
# array([14.1197, 14.2646,  3.9284, ..., 37.0622, 35.5971, 30.751 ])

# %%
df.Wind_Speed.nunique()
# Out:
# 2484

# %% [markdown]
# ### Q. 2) Find the number of times when the 'Weather is exactly Clear'.

# %%
df.groupby('Weather').get_group('Clear').head(20)
# Out:
#                               Date Weather Precip       Temp   App_Temp  Humi  \
# 223  2006-04-18 07:00:00.000 +0200   Clear   rain   8.688889   8.688889  0.93
# 309  2006-04-20 21:00:00.000 +0200   Clear   rain  12.266667  12.266667  0.99
# 337  2006-04-22 01:00:00.000 +0200   Clear   rain   9.355556   8.633333  0.96
# 338  2006-04-22 02:00:00.000 +0200   Clear   rain   9.861111   9.861111  0.96
# 357  2006-04-22 21:00:00.000 +0200   Clear   rain  12.494444  12.494444  0.91
# 358  2006-04-22 22:00:00.000 +0200   Clear   rain  12.244444  12.244444  0.89
# 359  2006-04-22 23:00:00.000 +0200   Clear   rain  11.416667  11.416667  0.92
# 360  2006-04-23 00:00:00.000 +0200   Clear   rain  10.555556  10.555556  0.95
# 361  2006-04-23 01:00:00.000 +0200   Clear   rain  10.466667  10.466667  0.93
# 363  2006-04-23 03:00:00.000 +0200   Clear   rain   9.355556   9.355556  0.96
# 386  2006-04-24 02:00:00.000 +0200   Clear   rain  12.383333  12.383333  0.80
# ...

# %% [markdown]
# #### Q. 3) Find the number of times when the 'Wind Speed was above 5 km/h'.

# %%
df[df.Wind_Speed > 5].tail()
# Out:
#                                 Date        Weather Precip       Temp  \
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy   rain  26.016667
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy   rain  24.583333
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy   rain  22.038889
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy   rain  21.522222
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy   rain  20.438889
#
#         App_Temp  Humi  Wind_Speed  Wind_Bear  Visibility  Loud  Pressure  \
# 96448  26.016667  0.43     10.9963       31.0     16.1000   0.0   1014.36
# 96449  24.583333  0.48     10.0947       20.0     15.5526   0.0   1015.16
# 96450  22.038889  0.56      8.9838       30.0     16.1000   0.0   1015.66
# 96451  21.522222  0.60     10.5294       20.0     16.1000   0.0   1015.95
# 96452  20.438889  0.61      5.8765       39.0     15.5204   0.0   1016.16
#
#                                 Daily Summary
# 96448  Partly cloudy starting in the morning.
# ...

# %% [markdown]
# ### Q. 4) Find out all the Null Values in the data.

# %%
df.isnull().sum()
# Out:
# Date               0
# Weather            0
# Precip           517
# Temp               0
# App_Temp           0
# Humi               0
# Wind_Speed         0
# Wind_Bear          0
# Visibility         0
# Loud               0
# Pressure           0
# Daily Summary      0
# dtype: int64

# %%
df.isnull().any()
# Out:
# Date             False
# Weather          False
# Precip            True
# Temp             False
# App_Temp         False
# Humi             False
# Wind_Speed       False
# Wind_Bear        False
# Visibility       False
# Loud             False
# Pressure         False
# Daily Summary    False
# dtype: bool

# %% [markdown]
# ### Q. 5) What is the mean 'Visibility' ?

# %%
df.head(2)
# Out:
#                             Date        Weather Precip      Temp  App_Temp  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy   rain  9.472222  7.388889
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy   rain  9.355556  7.227778
#
#    Humi  Wind_Speed  Wind_Bear  Visibility  Loud  Pressure  \
# 0  0.89     14.1197      251.0     15.8263   0.0   1015.13
# 1  0.86     14.2646      259.0     15.8263   0.0   1015.63
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.

# %%
df.Visibility.mean()
# Out:
# 10.347324929237148

# %% [markdown]
# ### Q. 6) What is the Standard Deviation of 'Pressure'  in this data?

# %%
df.Pressure.std()
# Out:
# 116.96990568258147

# %% [markdown]
# ### Q. 7) What is the Variance of 'Humidity' in this data ?

# %%
df.Humi.var()
# Out:
# 0.03820959171844407

# %% [markdown]
# ### Q. 8) Find all instances when 'Rain until afternoon' was recorded.

# %%
df['Daily Summary'].value_counts()
# Out:
# Mostly cloudy throughout the day.                                                                       20085
# Partly cloudy throughout the day.                                                                        9981
# Partly cloudy until night.                                                                               6169
# Partly cloudy starting in the morning.                                                                   5184
# Foggy in the morning.                                                                                    4201
#                                                                                                         ...
# Breezy starting overnight continuing until morning and foggy overnight.                                    24
# Mostly cloudy throughout the day and breezy starting overnight continuing until afternoon.                 24
# ...

# %%
# From above, "Rain until afternoon" was recorded 24 times

# %% [markdown]
# ### Q. 9) Find all instances when 'Wind Speed is above 24' and 'Visibility is above 25'.

# %%
df[(df.Wind_Speed < 14) & (df.Visibility < 15)]
# Out:
#                                 Date        Weather Precip       Temp  \
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy   rain   9.377778
# 5      2006-04-01 05:00:00.000 +0200  Partly Cloudy   rain   9.222222
# 6      2006-04-01 06:00:00.000 +0200  Partly Cloudy   rain   7.733333
# 8      2006-04-01 08:00:00.000 +0200  Partly Cloudy   rain  10.822222
# 9      2006-04-01 09:00:00.000 +0200  Partly Cloudy   rain  13.772222
# ...                              ...            ...    ...        ...
# 96389  2016-09-07 08:00:00.000 +0200  Partly Cloudy   rain  17.811111
# 96390  2016-09-07 09:00:00.000 +0200  Partly Cloudy   rain  19.977778
# 96410  2016-09-08 05:00:00.000 +0200  Mostly Cloudy   rain  16.738889
# 96434  2016-09-09 05:00:00.000 +0200          Clear   rain  15.016667
# 96437  2016-09-09 08:00:00.000 +0200  Partly Cloudy   rain  19.561111
#
#         App_Temp  Humi  Wind_Speed  Wind_Bear  Visibility  Loud  Pressure  \
# ...

# %% [markdown]
# ### Q. 10) What is the Mean value of each column against each 'Temperature' ?

# %%
df.Temp.mean()
# Out:
# 11.932678437511868

# %% [markdown]
# ### Q. 11) What is the Minimum & Maximum value of each column against each 'Temperature' ?

# %%
df.Temp.min()
# Out:
# -21.822222222222223

# %%
df.Temp.max()
# Out:
# 39.90555555555555

# %% [markdown]
# ### Q. 12) Find all instances when 'Weather is Clear' or 'Visibility is above 40'.

# %%
df[(df['Weather'] =='Clear') | (df.Visibility > 10)]
# Out:
#                                 Date        Weather Precip       Temp  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy   rain   9.472222
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy   rain   9.355556
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy   rain   9.377778
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy   rain   8.288889
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy   rain   8.755556
# ...                              ...            ...    ...        ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy   rain  26.016667
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy   rain  24.583333
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy   rain  22.038889
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy   rain  21.522222
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy   rain  20.438889
#
#         App_Temp  Humi  Wind_Speed  Wind_Bear  Visibility  Loud  Pressure  \
# ...

# %% [markdown]
# ### Q. 13) Find all instances when :
# A. 'Weather is Clear' and 'Relative Humidity is greater than 0.5'
# or
# B. 'Visibility is above 40'

# %%
df[(df['Weather'] == 'Clear') & (df['Humi'] > 0.5) | (df['Visibility'] > 14)]
# Out:
#                                 Date        Weather Precip       Temp  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy   rain   9.472222
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy   rain   9.355556
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy   rain   9.377778
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy   rain   8.288889
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy   rain   8.755556
# ...                              ...            ...    ...        ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy   rain  26.016667
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy   rain  24.583333
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy   rain  22.038889
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy   rain  21.522222
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy   rain  20.438889
#
#         App_Temp  Humi  Wind_Speed  Wind_Bear  Visibility  Loud  Pressure  \
# ...
